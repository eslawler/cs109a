# %%
import pandas as pd
import json

# %%
test = pd.read_json('data/star_table.json')

# %%
test
# Out:
#     credits                                   first_movie  gender  \
# 0        25                                         Bubot       1
# 1        55                                       Tommaso       0
# 2        17                                    Empty Nest       1
# 3        51                               All My Children       1
# 4        30                                    Järngänget       0
# 5        27                                     Après lui       1
# 6        23                           Una rosa de Francia       1
# 7        37                                  Frankenstein       0
# 8        17                                       Le défi       1
# 9         8                          Story of Miss Oxygen       1
# 10       51                             Question of Blood       1
# 11       31                            Somersaulting Dogs       1
# 12       42                          The Treasure Seekers       1
# ...
